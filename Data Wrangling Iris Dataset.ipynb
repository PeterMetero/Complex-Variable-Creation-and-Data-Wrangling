# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
df = pd.read_csv(url)

# %%
# Data cleaning
# Drop rows with missing values
df.dropna(inplace=True)

# %%
# Data transformation
# Convert species to a categorical variable
df['species'] = pd.Categorical(df['species'])

# %%
# Data aggregation
# Calculate mean sepal length and width for each species
species_summary = df.groupby('species')[['sepal_length', 'sepal_width']].mean().reset_index()
# Out:
# /tmp/ipykernel_4029/4239552403.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   species_summary = df.groupby('species')[['sepal_length', 'sepal_width']].mean().reset_index()

# %%
# Data visualization
plt.figure(figsize=(12, 6))

# Scatter plot of sepal length vs sepal width colored by species
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=df)
plt.title('Sepal Length vs Sepal Width by Species')

# Boxplot of sepal length by species
plt.figure(figsize=(10, 6))
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title('Boxplot of Sepal Length by Species')

# Bar plot of mean sepal length by species
plt.figure(figsize=(10, 6))
sns.barplot(x='species', y='sepal_length', data=species_summary)
plt.title('Mean Sepal Length by Species')

plt.show()
